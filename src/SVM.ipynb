# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
import sklearn.tree as tree
from sklearn.metrics import plot_confusion_matrix

# Classifiers 
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

dir_out = '../plots/'

# %%
dir_in = '../data/emg-4/'

col_names = []
for i in range(8):
    for j in range(8):
        col_names.append('muscle reading '+ str(i+1)+' sensor '+str(j+1))
col_names.append('gestures')

# Gesture classes were : rock - 0, scissors - 1, paper - 2, ok - 3

df = []        
for i in range(4):
    fn = dir_in + str(i) + '.csv'
    df_i = pd.read_csv(fn, header=None,index_col = False, names = col_names)
    print(len(df_i))
    if len(df) == 0:
        df = df_i
    else:
        df = df.append(df_i)
display(df.head())

print(len(df))
# Out:
# 2910
# 2903
# 2943
# 2922
#    muscle reading 1 sensor 1  muscle reading 1 sensor 2  \
# 0                       26.0                        4.0
# 1                      -47.0                       -6.0
# 2                      -19.0                       -8.0
# 3                        2.0                        3.0
# 4                        6.0                        0.0
#
#    muscle reading 1 sensor 3  muscle reading 1 sensor 4  \
# 0                        5.0                        8.0
# 1                       -5.0                       -7.0
# 2                       -8.0                       -8.0
# 3                        0.0                        2.0
# 4                        0.0                       -2.0
#
#    muscle reading 1 sensor 5  muscle reading 1 sensor 6  \
# 0                       -1.0                      -13.0
# 1                       13.0                       -1.0
# 2                      -21.0                       -6.0
# 3                        0.0                       22.0
# 4                      -14.0                       10.0
#
#    muscle reading 1 sensor 7  muscle reading 1 sensor 8  \
# 0                     -109.0                      -66.0
# 1                       35.0                      -10.0
# 2                      -79.0                       12.0
# 3                      106.0                      -14.0
# 4                      -51.0                        5.0
#
#    muscle reading 2 sensor 1  muscle reading 2 sensor 2  ...  \
# 0                       -9.0                        2.0  ...
# 1                       10.0                       -4.0  ...
# 2                        0.0                        5.0  ...
# 3                      -16.0                       -2.0  ...
# 4                        7.0                        0.0  ...
#
#    muscle reading 7 sensor 8  muscle reading 8 sensor 1  \
# 0                      -28.0                       61.0
# 1                      -25.0                       47.0
# 2                      -83.0                        7.0
# 3                      -38.0                      -11.0
# 4                       38.0                      -35.0
#
#    muscle reading 8 sensor 2  muscle reading 8 sensor 3  \
# 0                        4.0                        8.0
# 1                        6.0                        6.0
# 2                        7.0                        1.0
# 3                        4.0                        7.0
# 4                       -8.0                        2.0
#
#    muscle reading 8 sensor 4  muscle reading 8 sensor 5  \
# 0                        5.0                        4.0
# 1                        5.0                       13.0
# 2                       -8.0                        7.0
# 3                       11.0                       33.0
# 4                        6.0                      -13.0
#
#    muscle reading 8 sensor 6  muscle reading 8 sensor 7  \
# 0                       -7.0                      -59.0
# 1                       21.0                      111.0
# 2                       21.0                      114.0
# 3                       39.0                      119.0
# 4                      -24.0                     -112.0
#
#    muscle reading 8 sensor 8  gestures
# 0                       16.0         0
# 1                       15.0         0
# 2                       48.0         0
# 3                       43.0         0
# 4                      -69.0         0
#
# [5 rows x 65 columns]
# 11678

# %%
RANDOM_STATE_DATA = 0
X = df.drop(['gestures'],axis=1)
y = df['gestures']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE_DATA)

# %%
# DecisionTreeClassifier, grid search to find best parameter
RANDOM_STATE_MODEL = 42
clf = svm.SVC( random_state=RANDOM_STATE_MODEL)
param_grid = {'C': [0.1, 1, 10],
              'kernel': ['rbf','sigmoid'],
              'gamma': [0.001, 0.01]}
CV_clf = GridSearchCV(estimator = clf, param_grid = param_grid, cv =5, verbose = 3)

CV_clf.fit(X_train, y_train)
print(CV_clf.best_params_)
print(CV_clf.best_score_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.251, total=   8.6s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.6s remaining:    0.0s
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.252, total=   8.6s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   17.2s remaining:    0.0s
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.252, total=   8.7s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.252, total=   8.5s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.252, total=   8.8s
# [CV] C=0.1, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=0.1, gamma=0.001, kernel=sigmoid, score=0.124, total=   8.2s
# [CV] C=0.1, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=0.1, gamma=0.001, kernel=sigmoid, score=0.148, total=   8.4s
# [CV] C=0.1, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=0.1, gamma=0.001, kernel=sigmoid, score=0.151, total=   8.1s
# [CV] C=0.1, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=0.1, gamma=0.001, kernel=sigmoid, score=0.133, total=   8.3s
# [CV] C=0.1, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=0.1, gamma=0.001, kernel=sigmoid, score=0.135, total=   8.6s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.251, total=   8.8s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.252, total=   8.5s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.252, total=   8.5s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.252, total=   8.8s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.252, total=   8.9s
# [CV] C=0.1, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=0.1, gamma=0.01, kernel=sigmoid, score=0.130, total=   7.1s
# [CV] C=0.1, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=0.1, gamma=0.01, kernel=sigmoid, score=0.140, total=   7.2s
# [CV] C=0.1, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=0.1, gamma=0.01, kernel=sigmoid, score=0.147, total=   7.3s
# [CV] C=0.1, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=0.1, gamma=0.01, kernel=sigmoid, score=0.135, total=   7.3s
# [CV] C=0.1, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=0.1, gamma=0.01, kernel=sigmoid, score=0.139, total=   7.3s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.371, total=  10.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.353, total=   9.9s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.365, total=   9.9s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.366, total=  10.2s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.379, total=   9.8s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.124, total=   8.3s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.155, total=   8.3s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.155, total=   8.0s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.138, total=   7.8s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.137, total=   7.6s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.251, total=   9.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.252, total=   8.9s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.252, total=   9.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.252, total=   9.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.252, total=   9.3s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.132, total=   6.8s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.158, total=   6.9s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.151, total=   6.8s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.142, total=   6.8s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.141, total=   6.7s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.393, total=   9.3s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.376, total=   9.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.383, total=   9.2s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.392, total=   9.3s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.403, total=   9.6s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.134, total=   7.9s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.153, total=   8.0s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.157, total=   7.8s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.141, total=   7.5s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.135, total=   8.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.251, total=   9.5s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.252, total=   9.4s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.252, total=   9.4s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.252, total=   9.4s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.252, total=   9.2s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.139, total=   6.8s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.151, total=   7.1s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.148, total=   6.8s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.144, total=   7.0s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.140, total=   6.8s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  8.3min finished
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.3895321846468299

# %%
RANDOM_STATE_MODEL = 42
clf = svm.SVC(random_state=RANDOM_STATE_MODEL,
              kernel='rbf',#CV_clf.best_params_['kernel'],#'rbf'
              C=10,#CV_clf.best_params_['C'], #10
              gamma=0.001#CV_clf.best_params_['gamma'], #0.001
            )
clf.fit(X_train, y_train)
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)

# %%
labels = [0,1,2,3]
label_names = ['rock-0', 'scissors-1', 'paper-2', 'ok-3']

plt.rcParams["figure.figsize"] = (8, 8)

plot_confusion_matrix(clf, X_train, y_train,labels = labels, display_labels = label_names, xticks_rotation = 45, cmap=plt.cm.Blues)
plt.title('Confusion Matrix:\n SVM (Train)', fontsize = 20)
plt.tight_layout()
plt.savefig(dir_out +'CM_SVM_train.png')
plt.close()

plot_confusion_matrix(clf, X_test, y_test,labels = labels, display_labels = label_names, xticks_rotation = 45, cmap=plt.cm.Blues)
plt.title('Confusion Matrix:\n SVM (Test)', fontsize = 20)
plt.tight_layout()
plt.savefig(dir_out +'CM_SVM_test.png')
plt.close()

# %%
from plot_learning_curve import plot_learning_curve
from sklearn.model_selection import ShuffleSplit

# %%
title =  'Learning Curve of SVM'
cv = ShuffleSplit(n_splits=20, test_size=0.2, random_state=RANDOM_STATE_DATA)

plot_learning_curve(clf, title, X, y, ylim=(0.2, 1.01),
                    cv=cv, n_jobs=4)#, train_sizes = np.linspace(0.1, 1.0, 10))
plt.savefig(dir_out +'LC_SVM.png')
plt.close()
# Out:
# /Users/Strawberry/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
